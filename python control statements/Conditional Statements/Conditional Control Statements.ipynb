# %% [markdown]
# # Coditional Control Statement

# %% [markdown]
# **Conditional control statements** are used to execute block of statements based on `condition or selection`

# %% [markdown]
# These conditional control statements are two types
#
# `1. if`
#
# `2. match`

# %% [markdown]
# ## if statement

# %% [markdown]
# if statement is used to execute block of statements based on condition.
#
# 1. Simple if
#
# 2. if..else
#
# 3. if..elif..else (if..else ladder)
#
# 4. Nested if

# %% [markdown]
# ### simple if
#
# `if` without else is called **simple if**
#
# **syntax**
#
# if <condition>:
#
#     statement-1
#
#     statement-2
#
# statement-3

# %% [markdown]
# ![image.png](attachment:02c75f08-9703-4ab6-89de-fe3c3b5be1e8.png)

# %% [markdown]
# **Note**
#
# `pass keyword`
#
# Empty bloacks are not allowed in python
#
# A block must have one statement.
#
# `pass` is keyword used for representing empty blocks
#
# `pass` keyword do nothing (or) it acts like a place holder

# %%
# code

if 10>5:
    print("Hello")
print("Bye")

if 10>20:
    print("java")
print("Python")

if 10>5:
    pass
print("oracle")
# Out:
# Hello
# Bye
# Python
# oracle

# %% [markdown]
# **Note**
#
# All the statements inside the block must be at same indentation level.

# %%
# Example:
# Banking Application (withdraw)

accno=int(input("Account No :"))
balance=float(input("Balance :"))

total_amt=int(input("Amount to Withdraw :"))
if total_amt>=50000:
    print("Input PAN Details ")

if total_amt<balance:
    balance=balance-total_amt

print("AccountNo ",accno)
print("Balance ",balance)
# Out:
# Account No : 1236547895
# Balance : 10000
# Amount to Withdraw : 4000
# AccountNo  1236547895
# Balance  6000.0

# %% [markdown]
# ## if..else

# %% [markdown]
# This syntax define 2 blocks
#
# 1. if block
#
# 2. else block

# %% [markdown]
# ![image.png](attachment:cf0c26dd-bbca-4b28-a97a-c8c5059577fe.png)

# %% [markdown]
# **syntax**
#
# if <condition>:
#
#     statement-1
#
#     statement-2
#
# else:
#
#     statement-3
#
#     statement-4
#
# statement-5

# %%
# Example:
# Write a program to check whether a person is eligible to voting or not

age=int(input("Enter Age of the Person "))
if age>=18:
    print("Eligible to Vote")
else:
    print("Not Eligible Vote")
# Out:
# Enter Age of the Person  21
# Eligible to Vote

# %%
# Write a program to check whether a input number is even or odd

num=int(input("Enter Number "))
if num%2==0:
    print(num,"is even")
else:
    print(num,"is odd")
# Out:
# Enter Number  8
# 8 is even

# %%
# Write a program to check whether a input year is leap or not

year=int(input("Enter Year "))

if (year%4==0 and year%100!=0) or (year%400==0):
    print(year,"leap")
else:
    print(year,"not leap")
# Out:
# Enter Year  2024
# 2024 leap

# %% [markdown]
# **if..elif..else(if..else ladder)**

# %% [markdown]
# ![image.png](attachment:a7b9cd2f-fa63-41f5-8227-85f175516a42.png)

# %% [markdown]
# This syntax is used for checking multiple conditions
#
# **syntax**
#
#
# `if` <condition>:
#
#     statement-1
#
# `elif`<condition>:
#
#     statement-2
#
#
# `elif` <condition>:
#
#     statement-3
#
# ...
#
# `else:`
#
#     statement-n

# %%
# Write a program to find input number is +ve,-ve or zero

num=int(input("Enter any number "))

if num>0:
    print("+ve number")
elif num<0:
    print("-ve number")
else:
    print("zero")
# Out:
# Enter any number  45
# +ve number

# %% [markdown]
# n=int(input())
# if n%2!=0:
#     print("Weird")
# elif n>=2 and n<=5:
#     print("Not Weird")
# elif n>=6 and n<=20:
#     print("Weird")
# elif n>20:
#     print("Not Weird")

# %% [markdown]
# **Nested if**
#
# Defining if within if is called nested if (OR) if followed by if is called nested if.

# %% [markdown]
# **Syntax**
#
# `if <condition1>:`
#
#     if <condition2>:
#
#         statement-1
#
#     else:
#
#         statement-2
#
# `elif <condition3>:`
#
#     if <condition4>:
#
#           statement-3
#
#     else:
#
#           statement-4
# `else:`
#
#     statement-6

# %%
# Login Application

uname=input("UserName :")
pwd=input("Password :")

if uname=="uday":
    if pwd=="uday123":
        print("welcome")
    else:
        print("invalid password")
else:
    print("invalid username")
# Out:
# UserName : uday
# Password : uday123
# welcome

# %% [markdown]
# # match statement
#
# Python does not support switch..case statement (C,C++,Java Languages).
#
# Match statement is called selection statement, which execute block of statements based on the selection of value or equality of value.

# %% [markdown]
# ![image.png](attachment:9b368d2d-fd82-49af-8a3c-9a2b7545f504.png)

# %% [markdown]
# `Syntax`
#
# match(variable/value/expression):
#
#       case <value>:
#
#           statement-1
#
#       case <value>:
#
#            statement-2
#
#       case <value>:
#
#             statement-3
#
#        ….
#
#       case _:
#
#            statement-x

# %% [markdown]
# match statement read value of variable and compare with all the cases, if value of variable is equal to any case it execute block and stop. If value of variable does not match with any case, it executes default case (this default case is defined using _)

# %%
# Simple Calculator (+,-,*,/)

n1=int(input("Enter first number: "))
n2=int(input("Enter second number: "))
opr=input("Enter Operator (+,-,*,/) :")
match(opr):
    case '+':
        print(f'sum of {n1} and {n2} is {n1+n2}')
    case '-':
        print(f'diff of {n1} and {n2} is {n1-n2}')
    case '*':
        print(f'product of {n1} and {n2} is {n1*n2}')
    case '/':
        print(f'division of {n1} and {n2} is {n1/n2}')
    case _:
        print("invalid operator and try again...")
# Out:
# Enter first number:  8
# Enter second number:  4
# Enter Operator (+,-,*,/) : +
# sum of 8 and 4 is 12
